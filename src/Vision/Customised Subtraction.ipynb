# %%
#Customised Subtraction based on HSV value and find center of mass of the object after background removal

import cv2
import numpy as np
 
cap = cv2.VideoCapture("/afs/inf.ed.ac.uk/user/s18/s1891132/Downloads/video-1549400841.mp4")
frame_counter = 0

panel = np.zeros([100, 700], np.uint8)
cv2.namedWindow('panel')
 
def nothing(x):
    pass
 
cv2.createTrackbar('L - h', 'panel', 0, 179, nothing)
cv2.createTrackbar('U - h', 'panel', 179, 179, nothing)
 
cv2.createTrackbar('L - s', 'panel', 0, 255, nothing)
cv2.createTrackbar('U - s', 'panel', 255, 255, nothing)
 
cv2.createTrackbar('L - v', 'panel', 0, 255, nothing)
cv2.createTrackbar('U - v', 'panel', 255, 255, nothing)
 
cv2.createTrackbar('S ROWS', 'panel', 0, 480, nothing)
cv2.createTrackbar('E ROWS', 'panel', 480, 480, nothing)
cv2.createTrackbar('S COL', 'panel', 0, 640, nothing)
cv2.createTrackbar('E COL', 'panel', 640, 640, nothing)
 
 
 
while True:
    if frame_counter == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        frame_counter = 0 #Or whatever as long as it is the same as next line
        cap = cv2.VideoCapture("/afs/inf.ed.ac.uk/user/s18/s1891132/Downloads/video-1549400841.mp4")
        
    _, frame = cap.read()
    frame_counter = frame_counter+1
    
  
        
    s_r = cv2.getTrackbarPos('S ROWS', 'panel')
    e_r = cv2.getTrackbarPos('E ROWS', 'panel')
    s_c = cv2.getTrackbarPos('S COL', 'panel')
    e_c = cv2.getTrackbarPos('E COL', 'panel')
    roi = frame[s_r: e_r, s_c: e_c]
 
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)
 
    l_h = cv2.getTrackbarPos('L - h', 'panel')
    u_h = cv2.getTrackbarPos('U - h', 'panel')
    l_s = cv2.getTrackbarPos('L - s', 'panel')
    u_s = cv2.getTrackbarPos('U - s', 'panel')
    l_v = cv2.getTrackbarPos('L - v', 'panel')
    u_v = cv2.getTrackbarPos('U - v', 'panel')
 
    lower = np.array([l_h, l_s, l_v])
    upper = np.array([u_h, u_s, u_v])
 
    mask = cv2.inRange(hsv, lower, upper)
    mask_inv = cv2.bitwise_not(mask)
    
 
    bg = cv2.bitwise_and(roi, roi, mask=mask)
    fg = cv2.bitwise_and(roi, roi, mask=mask_inv)
    
    gray_image = cv2.cvtColor(bg, cv2.COLOR_BGR2GRAY)
 
    # convert the grayscale image to binary image
    ret,thresh = cv2.threshold(gray_image,127,255,0)
 
        
    # calculate moments of binary image
    M = cv2.moments(thresh)
 
    # calculate x,y coordinate of center
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
 
    # put text and highlight the center
    cv2.circle(bg, (cX, cY), 5, (255, 255, 255), -1)
    cv2.putText(bg, "centroid", (cX - 25, cY - 25),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
 
 
    cv2.imshow('bg', bg)
    cv2.imshow('fg', fg)
 
    cv2.imshow('panel', panel)
    cv2.waitKey(1000)
    k = cv2.waitKey(30) & 0xFF
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
#Customised Subtraction based on RGB value and find center of mass of the object after background removal

import cv2
import numpy as np
 
cap = cv2.VideoCapture("/afs/inf.ed.ac.uk/user/s18/s1891132/Downloads/video-1549400841.mp4")
frame_counter = 0

panel = np.zeros([100, 700], np.uint8)
cv2.namedWindow('panel')
 
def nothing(x):
    pass
 
cv2.createTrackbar('L - R', 'panel', 0, 255, nothing)
cv2.createTrackbar('U - R', 'panel', 255, 255, nothing)
 
cv2.createTrackbar('L - G', 'panel', 0, 255, nothing)
cv2.createTrackbar('U - G', 'panel', 255, 255, nothing)
 
cv2.createTrackbar('L - B', 'panel', 0, 255, nothing)
cv2.createTrackbar('U - B', 'panel', 255, 255, nothing)
 
cv2.createTrackbar('S ROWS', 'panel', 0, 480, nothing)
cv2.createTrackbar('E ROWS', 'panel', 480, 480, nothing)
cv2.createTrackbar('S COL', 'panel', 0, 640, nothing)
cv2.createTrackbar('E COL', 'panel', 640, 640, nothing)
 
 
 
while True:
    if frame_counter == cap.get(cv2.CAP_PROP_FRAME_COUNT):
        frame_counter = 0 #Or whatever as long as it is the same as next line
        cap = cv2.VideoCapture("/afs/inf.ed.ac.uk/user/s18/s1891132/Downloads/video-1549400841.mp4")
        
    _, frame = cap.read()
    frame_counter = frame_counter+1
    
  
        
    s_r = cv2.getTrackbarPos('S ROWS', 'panel')
    e_r = cv2.getTrackbarPos('E ROWS', 'panel')
    s_c = cv2.getTrackbarPos('S COL', 'panel')
    e_c = cv2.getTrackbarPos('E COL', 'panel')
    roi = frame[s_r: e_r, s_c: e_c]
 
 
    l_r = cv2.getTrackbarPos('L - R', 'panel')
    u_r = cv2.getTrackbarPos('U - R', 'panel')
    l_g = cv2.getTrackbarPos('L - G', 'panel')
    u_g = cv2.getTrackbarPos('U - G', 'panel')
    l_b = cv2.getTrackbarPos('L - B', 'panel')
    u_b = cv2.getTrackbarPos('U - B', 'panel')
 
    lower = np.array([l_r, l_g, l_b])
    upper = np.array([u_r, u_g, u_b])
 
    mask = cv2.inRange(roi, lower, upper)
    mask_inv = cv2.bitwise_not(mask)
    
 
    bg = cv2.bitwise_and(roi, roi, mask=mask)
    fg = cv2.bitwise_and(roi, roi, mask=mask_inv)
    
    gray_image = cv2.cvtColor(bg, cv2.COLOR_BGR2GRAY)
 
    # convert the grayscale image to binary image
    ret,thresh = cv2.threshold(gray_image,127,255,0)
 
        
    # calculate moments of binary image
    M = cv2.moments(thresh)
 
    # calculate x,y coordinate of center
    cX = int(M["m10"] / M["m00"])
    cY = int(M["m01"] / M["m00"])
 
    # put text and highlight the center
    cv2.circle(bg, (cX, cY), 5, (255, 255, 255), -1)
    cv2.putText(bg, "centroid", (cX - 25, cY - 25),cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
 
 
    cv2.imshow('bg', bg)
    cv2.imshow('fg', fg)
 
    cv2.imshow('panel', panel)
    cv2.waitKey(1000)
    k = cv2.waitKey(30) & 0xFF
    if k == 27:
        break

cap.release()
cv2.destroyAllWindows()
